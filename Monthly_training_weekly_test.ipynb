# %%
from datetime import date,timedelta

def get_start_end_dates(year, week):
     d = date(year,1,1)
     if(d.weekday()<= 3):
         d = d - timedelta(d.weekday())             
     else:
         d = d + timedelta(7-d.weekday())
     dlt = timedelta(days = (week-1)*7)
     return (d + dlt).strftime("%Y-%m-%d"),  (d + dlt + timedelta(days=6)).strftime("%Y-%m-%d")

# %%
from datetime import datetime
end,start = get_start_end_dates(2020,1)
print(get_start_end_dates(2020,1))
print(datetime.strptime(end,"%Y-%m-%d") - timedelta(weeks=4))
# Out:
# ('2019-12-30', '2020-01-05')
# 2019-12-02 00:00:00

# %%
import pandas as pd
import datetime as dt
from datetime import datetime
import eikon as ek
import calendar
import numpy as np
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")
from time import sleep

ek.set_app_key('1b68381d8f684b0183be832bab589097fd9942f2')

# Universe = ['RELI.NS','TCS.NS','HDBK.NS','HLL.NS','INFY.NS',
#             'HDFC.NS','KTKM.NS','BRTI.NS','HCLT.NS','ITC.NS',]


daily_returns = pd.DataFrame()

YEAR = 2013

start_date = str(YEAR-1) + '-12-01'
end_date = str(YEAR-1) + '-12-31'

Universe = get_top_rics_by_mktcap(10,start_date)

prices = ek.get_timeseries(rics=Universe,fields=['CLOSE'],
                            start_date=start_date,
                            end_date=end_date,
                            interval='daily',corax='adjusted')
returns = prices.pct_change()

# returns = np.log(prices) - np.log(prices.shift(1))


returns = returns.iloc[1:, :]

portwts = Get_EigenPort_Weights(returns)


for i in range(52):
    start_date,end_date = get_start_end_dates(YEAR,i)
    print("Testing for...")
    print(start_date,end_date)

    #To Show Plots
#     portwts.plot(kind='bar', legend=False)
#     plt.title("Second E.V. Eigenportfolio")
#     plt.show()
    
    prices = ek.get_timeseries(rics=Universe,fields=['CLOSE'],
                            start_date=start_date,
                            end_date=end_date,
                            interval='daily',corax='adjusted')
    sleep(1)
    returns = prices.pct_change()
    returns = returns.iloc[1:, :]
#     portwts.loc[portwts['Investment Weight'] < 0] = 0 
#     portwts = portwts/portwts.sum()
    if(i > 0):
        
        rets = get_cumulative_returns_over_time(returns,portwts) + max((daily_returns.values[-1][0]),-0.5)
    else:
        rets = get_cumulative_returns_over_time(returns,portwts)
        
    daily_returns = daily_returns.append(rets)
    
    print("Training for...")
    print((datetime.strptime(end_date,"%Y-%m-%d") - timedelta(weeks=4)),end_date)

    prices = ek.get_timeseries(rics=Universe,fields=['CLOSE'],
                        start_date=(datetime.strptime(end_date,"%Y-%m-%d") - timedelta(weeks=4)),
                        end_date=end_date,
                        interval='daily',corax='adjusted')
    
    returns = prices.pct_change()
    returns = returns.iloc[1:, :]
    
#     Universe = get_top_rics_by_mktcap(10,start_date)
    portwts = Get_EigenPort_Weights(returns)
    

    
nifty = ek.get_timeseries(rics=['.NSEI'],fields=['CLOSE'],
                            start_date=str(daily_returns.index[0].date()),
                            end_date=str(daily_returns.index[-1].date()),
                            interval='daily',corax='adjusted')
indexreturns = nifty.pct_change()
indexreturns = indexreturns.iloc[1:, :]


plt.plot(daily_returns,label='EigenPortfolio')
plt.plot((((1+indexreturns).cumprod(axis=0))-1),label='Benchmark (Nifty 50)')
plt.grid()
plt.legend()
# Out:
# Testing for...
# 2012-12-24 2012-12-30
# Training for...
# 2012-12-02 00:00:00 2012-12-30
# Testing for...
# 2012-12-31 2013-01-06
# Training for...
# 2012-12-09 00:00:00 2013-01-06
# Testing for...
# 2013-01-07 2013-01-13
# Training for...
# 2012-12-16 00:00:00 2013-01-13
# Testing for...
# 2013-01-14 2013-01-20
# Training for...
# 2012-12-23 00:00:00 2013-01-20
# Testing for...
# 2013-01-21 2013-01-27
# Training for...
# 2012-12-30 00:00:00 2013-01-27
# Testing for...
# 2013-01-28 2013-02-03
# Training for...
# 2013-01-06 00:00:00 2013-02-03
# Testing for...
# 2013-02-04 2013-02-10
# Training for...
# 2013-01-13 00:00:00 2013-02-10
# Testing for...
# 2013-02-11 2013-02-17
# Training for...
# 2013-01-20 00:00:00 2013-02-17
# Testing for...
# 2013-02-18 2013-02-24
# Training for...
# 2013-01-27 00:00:00 2013-02-24
# Testing for...
# 2013-02-25 2013-03-03
# Training for...
# 2013-02-03 00:00:00 2013-03-03
# Testing for...
# 2013-03-04 2013-03-10
# Training for...
# 2013-02-10 00:00:00 2013-03-10
# Testing for...
# 2013-03-11 2013-03-17
# Training for...
# 2013-02-17 00:00:00 2013-03-17
# Testing for...
# 2013-03-18 2013-03-24
# Training for...
# 2013-02-24 00:00:00 2013-03-24
# Testing for...
# 2013-03-25 2013-03-31
# Training for...
# 2013-03-03 00:00:00 2013-03-31
# Testing for...
# 2013-04-01 2013-04-07
# Training for...
# 2013-03-10 00:00:00 2013-04-07
# Testing for...
# 2013-04-08 2013-04-14
# Training for...
# 2013-03-17 00:00:00 2013-04-14
# Testing for...
# 2013-04-15 2013-04-21
# Training for...
# 2013-03-24 00:00:00 2013-04-21
# Testing for...
# 2013-04-22 2013-04-28
# Training for...
# 2013-03-31 00:00:00 2013-04-28
# Testing for...
# 2013-04-29 2013-05-05
# Training for...
# 2013-04-07 00:00:00 2013-05-05
# Testing for...
# 2013-05-06 2013-05-12
# Training for...
# 2013-04-14 00:00:00 2013-05-12
# Testing for...
# 2013-05-13 2013-05-19
# Training for...
# 2013-04-21 00:00:00 2013-05-19
# Testing for...
# 2013-05-20 2013-05-26
# Training for...
# 2013-04-28 00:00:00 2013-05-26
# Testing for...
# 2013-05-27 2013-06-02
# Training for...
# 2013-05-05 00:00:00 2013-06-02
# Testing for...
# 2013-06-03 2013-06-09
# Training for...
# 2013-05-12 00:00:00 2013-06-09
# Testing for...
# 2013-06-10 2013-06-16
# Training for...
# 2013-05-19 00:00:00 2013-06-16
# Testing for...
# 2013-06-17 2013-06-23
# Training for...
# 2013-05-26 00:00:00 2013-06-23
# Testing for...
# 2013-06-24 2013-06-30
# Training for...
# 2013-06-02 00:00:00 2013-06-30
# Testing for...
# 2013-07-01 2013-07-07
# Training for...
# 2013-06-09 00:00:00 2013-07-07
# Testing for...
# 2013-07-08 2013-07-14
# Training for...
# 2013-06-16 00:00:00 2013-07-14
# Testing for...
# 2013-07-15 2013-07-21
# Training for...
# 2013-06-23 00:00:00 2013-07-21
# Testing for...
# 2013-07-22 2013-07-28
# Training for...
# 2013-06-30 00:00:00 2013-07-28
# Testing for...
# 2013-07-29 2013-08-04
# Training for...
# 2013-07-07 00:00:00 2013-08-04
# Testing for...
# 2013-08-05 2013-08-11
# Training for...
# 2013-07-14 00:00:00 2013-08-11
# Testing for...
# 2013-08-12 2013-08-18
# Training for...
# 2013-07-21 00:00:00 2013-08-18
# Testing for...
# 2013-08-19 2013-08-25
# Training for...
# 2013-07-28 00:00:00 2013-08-25
# Testing for...
# 2013-08-26 2013-09-01
# Training for...
# 2013-08-04 00:00:00 2013-09-01
# Testing for...
# 2013-09-02 2013-09-08
# Training for...
# 2013-08-11 00:00:00 2013-09-08
# Testing for...
# 2013-09-09 2013-09-15
# Training for...
# 2013-08-18 00:00:00 2013-09-15
# Testing for...
# 2013-09-16 2013-09-22
# Training for...
# 2013-08-25 00:00:00 2013-09-22
# Testing for...
# 2013-09-23 2013-09-29
# Training for...
# 2013-09-01 00:00:00 2013-09-29
# Testing for...
# 2013-09-30 2013-10-06
# Training for...
# 2013-09-08 00:00:00 2013-10-06
# Testing for...
# 2013-10-07 2013-10-13
# Training for...
# 2013-09-15 00:00:00 2013-10-13
# Testing for...
# 2013-10-14 2013-10-20
# Training for...
# 2013-09-22 00:00:00 2013-10-20
# Testing for...
# 2013-10-21 2013-10-27
# Training for...
# 2013-09-29 00:00:00 2013-10-27
# Testing for...
# 2013-10-28 2013-11-03
# Training for...
# 2013-10-06 00:00:00 2013-11-03
# Testing for...
# 2013-11-04 2013-11-10
# Training for...
# 2013-10-13 00:00:00 2013-11-10
# Testing for...
# 2013-11-11 2013-11-17
# Training for...
# 2013-10-20 00:00:00 2013-11-17
# Testing for...
# 2013-11-18 2013-11-24
# Training for...
# 2013-10-27 00:00:00 2013-11-24
# Testing for...
# 2013-11-25 2013-12-01
# Training for...
# 2013-11-03 00:00:00 2013-12-01
# Testing for...
# 2013-12-02 2013-12-08
# Training for...
# 2013-11-10 00:00:00 2013-12-08
# Testing for...
# 2013-12-09 2013-12-15
# Training for...
# 2013-11-17 00:00:00 2013-12-15
# Testing for...
# 2013-12-16 2013-12-22
# Training for...
# 2013-11-24 00:00:00 2013-12-22

# %%
def Get_EigenPort_Weights(data):
    universe = data.columns.tolist()

    covariance_matrix = data.cov()
    
    D, S = np.linalg.eig(np.linalg.inv(covariance_matrix))
    S_sum = (S[:,-1]/np.sum(S[:,-1])) #+ (S[:,-2]/np.sum(S[:,-2])) + (S[:,-3]/np.sum(S[:,-3]))
    eigenportfolio_final = S_sum/np.sum(S_sum)
#     SharpeList = []
#     for i in range(len(S)):
#         eigenportfolio_1 = S[:,-i] / np.sum(S[:,-i]) # Normalize to sum to 1
#         eigenportfolio = pd.DataFrame(data= eigenportfolio_1, columns = ['Investment Weight'], index = universe)
#         cumulative_returns = get_cumulative_returns_over_time(data, eigenportfolio).values
#         SharpeList.append(cumulative_returns[-1][0]/np.std(cumulative_returns))    
    
#     eigenportfolio_final = S[:,-np.argmax(SharpeList)] / np.sum(S[:,-np.argmax(SharpeList)]) # Normalize to sum to 1
    eigenportfolio = pd.DataFrame(data= eigenportfolio_final, columns = ['Investment Weight'], index = universe)
    return eigenportfolio

def get_top_rics_by_mktcap(top,date):
    return ek.get_data("0#.NIFTY100","TR.CompanyMarketCap",{'Sdate':date})[0].sort_values(by='Company Market Cap',ascending=False).Instrument[:top].tolist()

def get_cumulative_returns_over_time(sample, weights):
    return (((1+sample).cumprod(axis=0))-1).dot(weights)

# %%
import numpy as np

covariance_matrix = in_sample.cov()

D, S = np.linalg.eigh(covariance_matrix)

eigenportfolio_1 = S[:,-1] / np.sum(S[:,-1]) # Normalize to sum to 1

eigenportfolio_2 = S[:,-2] / np.sum(S[:,-2]) # Normalize to sum to 1


# Setup Portfolios
eigenportfolio = pd.DataFrame(data= eigenportfolio_1, columns = ['Investment Weight'], index = tickers)
eigenportfolio2 = pd.DataFrame(data= eigenportfolio_2, columns = ['Investment Weight'], index = tickers)

# Plot
# %matplotlib inline
import matplotlib.pyplot as plt
f = plt.figure()

ax = plt.subplot(121)
eigenportfolio.plot(kind='bar', ax=ax, legend=False)
plt.title("Max E.V. Eigenportfolio")
ax = plt.subplot(122)
eigenportfolio2.plot(kind='bar', ax=ax, legend=False)
plt.title("2nd E.V. Eigenportfolio")
# Out:
# Text(0.5, 1.0, '2nd E.V. Eigenportfolio')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def get_cumulative_returns_over_time(sample, weights):
    return (((1+sample).cumprod(axis=0))-1).dot(weights)

in_sample_ind = np.arange(0, (returns.shape[0]-training_period+1))
out_sample_ind = np.arange((returns.shape[0]-training_period+1), returns.shape[0])

cumulative_returns = get_cumulative_returns_over_time(returns, eigenportfolio).values

f = plt.figure(figsize=(10,4))

ax = plt.subplot(121)
ax.plot(cumulative_returns[in_sample_ind], 'black')
ax.plot(out_sample_ind,cumulative_returns[out_sample_ind], 'r')
plt.title("Eigenportfolio")

ax = plt.subplot(122)
plt.plot((((1+indexreturns).cumprod(axis=0))-1))
plt.title("Nifty50")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-215-306d452497c6> in <module>
#       8 out_sample_ind = np.arange((returns.shape[0]-training_period+1), returns.shape[0])
#       9
# ---> 10 cumulative_returns = get_cumulative_returns_over_time(returns, eigenportfolio).values
#      11
#      12 f = plt.figure(figsize=(10,4))
#
# <ipython-input-215-306d452497c6> in get_cumulative_returns_over_time(sample, weights)
#       3
#       4 def get_cumulative_returns_over_time(sample, weights):
# ----> 5     return (((1+sample).cumprod(axis=0))-1).dot(weights)
#       6
#       7 in_sample_ind = np.arange(0, (returns.shape[0]-training_period+1))
#
# ~/Documents/kite/kite/lib/python3.8/site-packages/pandas/core/frame.py in dot(self, other)
#    1121             common = self.columns.union(other.index)
#    1122             if len(common) > len(self.columns) or len(common) > len(other.index):
# -> 1123                 raise ValueError("matrices are not aligned")
#    1124
#    1125             left = self.reindex(columns=common, copy=False)
#
# ValueError: matrices are not aligned

# %%
# eigenportfolio.sort_index()
returns.sort_index(axis=1)
# Out:
# CLOSE        COAL.NS   HDBK.NS   HDFC.NS   ICBK.NS   INFY.NS    ITC.NS  \
# Date
# 2015-01-06 -0.000789 -0.015567 -0.049309 -0.042418 -0.020893 -0.025710
# 2015-01-07 -0.013818  0.002919 -0.000319 -0.027039  0.004785 -0.016944
# 2015-01-08  0.012677  0.021005  0.022320  0.027199  0.005042  0.022323
# 2015-01-09 -0.011596  0.011193 -0.010827 -0.016117  0.051179 -0.008154
# 2015-01-12 -0.045861 -0.008815  0.017252  0.013749  0.020005 -0.002647
# 2015-01-13  0.009361 -0.003826 -0.005358 -0.016304 -0.012784  0.008801
# 2015-01-14  0.005537  0.000571 -0.001959 -0.011734  0.019029 -0.034898
# 2015-01-15  0.014455  0.030345  0.065215  0.047343  0.002631  0.022672
# 2015-01-16  0.028769  0.008257  0.003350  0.002834 -0.007473  0.010243
# 2015-01-19  0.000396  0.003196 -0.014190  0.019641 -0.007459 -0.005000
# 2015-01-20  0.008175  0.016326  0.058425  0.019263  0.010321  0.036572
# 2015-01-21  0.024980 -0.000979  0.031240  0.001903  0.021514 -0.051980
# 2015-01-22  0.011612  0.001275 -0.007021  0.003664  0.012236  0.000000
# 2015-01-23 -0.004289  0.021102  0.001250  0.002434  0.008468 -0.007244
# 2015-01-27 -0.030530  0.029967  0.023798  0.034529 -0.035462  0.032050
# 2015-01-28  0.003005 -0.014618  0.025074  0.001434  0.003768  0.006516
# 2015-01-29 -0.023059  0.034629 -0.026022 -0.009764  0.000443  0.019284
# 2015-01-30 -0.037605 -0.016119 -0.025954 -0.051538 -0.001678 -0.003378
#
# CLOSE        ONGC.NS   RELI.NS    SBI.NS    TCS.NS
# Date
# 2015-01-06 -0.061528 -0.049169 -0.041087 -0.036866
# 2015-01-07  0.020648  0.030631  0.000834 -0.011812
# 2015-01-08  0.005611 -0.017483  0.015659  0.010795
# 2015-01-09  0.029662  0.021945 -0.005412  0.028030
# 2015-01-12 -0.009983 -0.010447  0.012863 -0.001035
# 2015-01-13 -0.019879 -0.008798 -0.006513 -0.004702
# 2015-01-14  0.012640 -0.009467 -0.001311  0.009628
# 2015-01-15 -0.001306  0.031063  0.051198  0.006800
# 2015-01-16  0.008429  0.005214 -0.015142 -0.002737
# 2015-01-19  0.004756  0.014121 -0.007291 -0.008353
# 2015-01-20  0.005164  0.025916  0.015967 -0.004202
# 2015-01-21 -0.011558  0.004986  0.025303  0.005339
# 2015-01-22  0.021366 -0.025192 -0.004752 -0.000099
# 2015-01-23 -0.011873  0.002997  0.008625 -0.003959
# 2015-01-27  0.001287  0.000451  0.007940 -0.000619
# 2015-01-28  0.013286  0.021753  0.013786  0.015008
# 2015-01-29 -0.011702  0.023606 -0.022714  0.001989
# 2015-01-30  0.004565 -0.012501 -0.055199 -0.024601

# %%
covariance_matrix = in_sample.cov()

D, S = np.linalg.eigh(covariance_matrix)

in_sample_ind = np.arange(0, (returns.shape[0]-training_period+1))
out_sample_ind = np.arange((returns.shape[0]-training_period+1), returns.shape[0])

SharpeList = []
    
for i in range(len(S)):
    eigenportfolio_1 = S[:,-i] / np.sum(S[:,-i]) # Normalize to sum to 1
    eigenportfolio = pd.DataFrame(data= eigenportfolio_1, columns = ['Investment Weight'], index = tickers)

    cumulative_returns = get_cumulative_returns_over_time(returns, eigenportfolio).values
    SharpeList.append(cumulative_returns[-1][0]/np.std(cumulative_returns))
    
print(np.argmax(SharpeList))
# Out:
# [1.6787639102874272, 2.243213455244665, 2.3204141674006085, -2.308655185355843, 2.4620741653552476, 2.468403493502742, 1.7397023528875737, 0.2933620663885827, -0.5627062724594541, 2.8389051091077055]
# 9

# %%
len(S)
# Out:
# 10

# %%
    import numpy as np
    
    covariance_matrix = in_sample.cov().values
    inv_cov_mat = np.linalg.pinv(covariance_matrix) # Use pseudo-inverse incase matrix is singular / ill-conditioned
    
    # Construct minimum variance weights
    ones = np.ones(len(inv_cov_mat))
    inv_dot_ones = np.dot(inv_cov_mat, ones)
    min_var_weights = inv_dot_ones/ np.dot( inv_dot_ones , ones)
    
    min_var_portfolio = pd.DataFrame(data= min_var_weights, columns = ['Investment Weight'], index = tickers)
    min_var_portfolio
# Out:
#          Investment Weight
# CLOSE
# RELI.NS           0.080581
# TCS.NS            0.035185
# HDBK.NS           0.063321
# HLL.NS            0.378907
# INFY.NS           0.105514
# HDFC.NS          -0.036194
# KTKM.NS          -0.030257
# BRTI.NS           0.058191
# HCLT.NS           0.206516
# ITC.NS            0.138236

# %%
# Largest eigenvalue eigenportfolio
D, S = np.linalg.eigh(covariance_matrix)
eigenportfolio_1 = S[:,-1] / np.sum(S[:,-1]) # Normalize to sum to 1
eigenportfolio_largest = pd.DataFrame(data= eigenportfolio_1, columns = ['Investment Weight'], index = tickers)

# Plot
# %matplotlib inline
import matplotlib.pyplot as plt
f = plt.figure()
ax = plt.subplot(121)
min_var_portfolio.plot(kind='bar', ax=ax, legend=False)
plt.title("Min Var Portfolio")
ax = plt.subplot(122)
eigenportfolio_largest.plot(kind='bar', ax=ax, legend=False)
plt.title("Max E.V. Eigenportfolio")
print(min_var_portfolio)
# Out:
#          Investment Weight
# CLOSE
# RELI.NS           0.080581
# TCS.NS            0.035185
# HDBK.NS           0.063321
# HLL.NS            0.378907
# INFY.NS           0.105514
# HDFC.NS          -0.036194
# KTKM.NS          -0.030257
# BRTI.NS           0.058191
# HCLT.NS           0.206516
# ITC.NS            0.138236

# %%
def get_cumulative_returns_over_time(sample, weights):
    return (((1+sample).cumprod(axis=0))-1).dot(weights)

in_sample_ind = np.arange(0, (returns.shape[0]-training_period+1))
out_sample_ind = np.arange((returns.shape[0]-training_period+1), returns.shape[0])

cumulative_returns = get_cumulative_returns_over_time(returns, min_var_portfolio).values
cumulative_returns_largest = get_cumulative_returns_over_time(returns, eigenportfolio_largest).values


f = plt.figure(figsize=(10,4))

ax = plt.subplot(121)
ax.plot(cumulative_returns[in_sample_ind], 'black')
ax.plot(out_sample_ind,cumulative_returns[out_sample_ind], 'r')
plt.title("Minimum Variance Portfolio")

ax = plt.subplot(122)
ax.plot(cumulative_returns_largest[in_sample_ind], 'black')
ax.plot(out_sample_ind,cumulative_returns_largest[out_sample_ind], 'r')
plt.title("Eigenportfolio")
# Out:
# Text(0.5, 1.0, 'Eigenportfolio')
